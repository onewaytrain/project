# %% [markdown]
# 1. 일별 자전거 이용건수
# 2. 대여시간대별, 요일별 자전거 이용건수
# 3. 주말, 평일 이용건수
# 4. 인기명소

# %%
# 데이터 불러오기, 데이터 병합

import pandas as pd

bikes_t = {}

for i in range(1,4):
    bikes_t[i] = pd.read_csv(f'data\서울특별시 공공자전거 대여이력 정보_240{i}.csv', encoding='cp949')

# %%
for i in range(1,4):
    print(bikes_t[i].shape)
# Out:
# (2053893, 17)
# (2101129, 17)
# (3250056, 17)

# %%
bikes = pd.concat(bikes_t, ignore_index=True)
bikes.head()
# Out:
#        자전거번호                 대여일시  대여 대여소번호          대여 대여소명  대여거치대  \
# 0  SPB-46712  2024-01-01 00:04:10      4804          동서울농협 앞      0
# 1  SPB-35089  2024-01-01 00:00:10      4169           신대방삼거리      0
# 2  SPB-36386  2024-01-01 00:03:13       540  군자역 7번출구 베스트샵 앞      0
# 3  SPB-61278  2024-01-01 00:02:42      1139        용문사 버스정류장      0
# 4  SPB-36848  2024-01-01 00:03:02      3416        동묘앞역 6번출구      0
#
#                   반납일시 반납대여소번호         반납대여소명 반납거치대  이용시간(분)  이용거리(M)    생년  \
# 0  2024-01-01 00:05:13   01416       상봉역 3번출구     0        1     0.00  2002
# 1  2024-01-01 00:06:23   00251  서울지방병무청 버스정류장     0        6  1147.58  1993
# 2  2024-01-01 00:06:33   03509       세종사이버대학교     0        3   642.13  2004
# 3  2024-01-01 00:07:24   00701       목동사거리 부근     0        4   830.00    \N
# 4  2024-01-01 00:07:33   00346         맥스타일 앞     0        4   791.08  1995
#
#     성별 이용자종류  대여대여소ID  반납대여소ID  자전거구분
# 0    M   내국인  ST-2630   ST-850  일반자전거
# 1  NaN   내국인  ST-2654   ST-299  일반자전거
# 2    F   내국인   ST-253  ST-1194  일반자전거
# 3    M   내국인   ST-533   ST-309  일반자전거
# 4    M   내국인  ST-1813   ST-162  일반자전거

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7405078 entries, 0 to 7405077
# Data columns (total 17 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   자전거번호     object
#  1   대여일시      object
#  2   대여 대여소번호  int64
#  3   대여 대여소명   object
#  4   대여거치대     int64
#  5   반납일시      object
#  6   반납대여소번호   object
#  7   반납대여소명    object
#  8   반납거치대     object
#  9   이용시간(분)   int64
#  10  이용거리(M)   float64
#  11  생년        object
#  12  성별        object
#  13  이용자종류     object
#  14  대여대여소ID   object
#  15  반납대여소ID   object
#  16  자전거구분     object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 960.4+ MB

# %% [markdown]
# ## 날짜 데이터 변경 : pd.to_datetime(변수명)
# - dt 액세서 (날짜 데이터로 되어있을때 이용 가능)
#     - 변수명.dt.year
#     - 변수명.dt.month
#     - 변수명.dt.weekday (요일, 숫자로 0~6(월~일))
#     - 변수명.dt.hour

# %%
# 일자별, 요일별, 주말구분별, 대여시간대별 따릉이 이용건수 파악
# 대여별, 일자, 요일, 대여시간대, 주말구분 컬럼 추가 

bikes['대여일'] = pd.to_datetime(bikes['대여일시'])
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7405078 entries, 0 to 7405077
# Data columns (total 18 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   자전거번호     object
#  1   대여일시      object
#  2   대여 대여소번호  int64
#  3   대여 대여소명   object
#  4   대여거치대     int64
#  5   반납일시      object
#  6   반납대여소번호   object
#  7   반납대여소명    object
#  8   반납거치대     object
#  9   이용시간(분)   int64
#  10  이용거리(M)   float64
#  11  생년        object
#  12  성별        object
#  13  이용자종류     object
#  14  대여대여소ID   object
#  15  반납대여소ID   object
#  16  자전거구분     object
#  17  대여일       datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(13)
# memory usage: 1016.9+ MB

# %%
# 월,일자,시간대 컬럼 추가

bikes['월'] = bikes['대여일'].dt.month
bikes['일자'] = bikes['대여일'].dt.day
bikes['시간대'] = bikes['대여일'].dt.hour

bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7405078 entries, 0 to 7405077
# Data columns (total 21 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   자전거번호     object
#  1   대여일시      object
#  2   대여 대여소번호  int64
#  3   대여 대여소명   object
#  4   대여거치대     int64
#  5   반납일시      object
#  6   반납대여소번호   object
#  7   반납대여소명    object
#  8   반납거치대     object
#  9   이용시간(분)   int64
#  10  이용거리(M)   float64
#  11  생년        object
#  12  성별        object
#  13  이용자종류     object
#  14  대여대여소ID   object
#  15  반납대여소ID   object
#  16  자전거구분     object
#  17  대여일       datetime64[ns]
#  18  월         int32
#  19  일자        int32
#  20  시간대       int32
# dtypes: datetime64[ns](1), float64(1), int32(3), int64(3), object(13)
# memory usage: 1.1+ GB

# %%
# 요일
bikes['요일_n'] = bikes['대여일'].dt.weekday
bikes['요일_n'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int32)

# %%
bikes['요일_n'].value_counts().sort_index()
# Out:
# 요일_n
# 0     977123
# 1    1088280
# 2    1173864
# 3    1147832
# 4    1146668
# 5     987407
# 6     883904
# Name: count, dtype: int64

# %%
bikes.head()
# Out:
#        자전거번호                 대여일시  대여 대여소번호          대여 대여소명  대여거치대  \
# 0  SPB-46712  2024-01-01 00:04:10      4804          동서울농협 앞      0
# 1  SPB-35089  2024-01-01 00:00:10      4169           신대방삼거리      0
# 2  SPB-36386  2024-01-01 00:03:13       540  군자역 7번출구 베스트샵 앞      0
# 3  SPB-61278  2024-01-01 00:02:42      1139        용문사 버스정류장      0
# 4  SPB-36848  2024-01-01 00:03:02      3416        동묘앞역 6번출구      0
#
#                   반납일시 반납대여소번호         반납대여소명 반납거치대  이용시간(분)  ...   성별 이용자종류  \
# 0  2024-01-01 00:05:13   01416       상봉역 3번출구     0        1  ...    M   내국인
# 1  2024-01-01 00:06:23   00251  서울지방병무청 버스정류장     0        6  ...  NaN   내국인
# 2  2024-01-01 00:06:33   03509       세종사이버대학교     0        3  ...    F   내국인
# 3  2024-01-01 00:07:24   00701       목동사거리 부근     0        4  ...    M   내국인
# 4  2024-01-01 00:07:33   00346         맥스타일 앞     0        4  ...    M   내국인
#
#    대여대여소ID  반납대여소ID  자전거구분                 대여일  월 일자  시간대  요일_n
# 0  ST-2630   ST-850  일반자전거 2024-01-01 00:04:10  1  1    0     0
# 1  ST-2654   ST-299  일반자전거 2024-01-01 00:00:10  1  1    0     0
# 2   ST-253  ST-1194  일반자전거 2024-01-01 00:03:13  1  1    0     0
# 3   ST-533   ST-309  일반자전거 2024-01-01 00:02:42  1  1    0     0
# 4  ST-1813   ST-162  일반자전거 2024-01-01 00:03:02  1  1    0     0
#
# [5 rows x 22 columns]

# %%
weekdays = {0:'월', 1:'화', 2:'수', 3:'목', 4:'금', 5:'토', 6:'일'}
bikes['요일'] = bikes['요일_n'].map(weekdays)
bikes['요일'].unique()
# Out:
# array(['월', '화', '수', '목', '금', '토', '일'], dtype=object)

# %%
# 주말구분 열 생성

weekend = {'월':'평일','화':'평일','수':'평일','목':'평일','금':'평일','토':'주말','일':'주말'}
bikes['주말구분'] = bikes['요일'].map(weekend)
bikes['주말구분'].unique()
# Out:
# array(['평일', '주말'], dtype=object)

# %% [markdown]
# 일자별 따릉이 이용건수

# %%
# 1월 일자별 대여현황

daily_ride_01 = bikes.query('월==1').groupby('일자',as_index=False)['자전거번호'].count()
daily_ride_01.head()
# Out:
#    일자  자전거번호
# 0   1  48927
# 1   2  89691
# 2   3  74474
# 3   4  93416
# 4   5  97979

# %%
# 시각화

import seaborn as sns
import matplotlib.pyplot as plt 

plt.rc('font', family='Malgun Gothic')
plt.figure(figsize=(7,3))
plt.title('2024년 1월 일자별 현황')
sns.barplot(data=daily_ride_01, x='일자',y='자전거번호')
# Out:
# <Axes: title={'center': '2024년 1월 일자별 현황'}, xlabel='일자', ylabel='자전거번호'>

# %%
# 2월

daily_ride_02 = bikes.query('월==2').groupby('일자',as_index=False)['자전거번호'].count()

# 3월

daily_ride_03 = bikes.query('월==3').groupby('일자',as_index=False)['자전거번호'].count()

# %%
# 1,2,3월 --> subplot

fig, axes = plt.subplots(1,3,figsize=(15,3))

sns.barplot(data=daily_ride_01, x='일자',y='자전거번호',ax=axes[0])
axes[0].set_title('2024년 1월 일자별 현황', fontsize=10)

sns.barplot(data=daily_ride_02, x='일자',y='자전거번호',ax=axes[1])
axes[1].set_title('2024년 2월 일자별 현황', fontsize=10)

sns.barplot(data=daily_ride_03, x='일자',y='자전거번호',ax=axes[2])
axes[2].set_title('2024년 3월 일자별 현황', fontsize=10)

# 그래프 간 간격 조정
plt.tight_layout()
plt.show()

# %%
# 대여시간대별 따릉이 이용건수

hourly_ride = bikes.groupby('시간대', as_index=False)[['자전거번호']].count()

plt.figure(figsize=(7,3))
plt.title('2024년 대여시간대별 현황')
sns.barplot(data=hourly_ride, x='시간대',y='자전거번호')
# Out:
# <Axes: title={'center': '2024년 대여시간대별 현황'}, xlabel='시간대', ylabel='자전거번호'>

# %%
# 요일별 따릉이 인원수

day_ride = bikes.groupby('요일', as_index=False)[['자전거번호']].count()

plt.figure(figsize=(7,3))
plt.title('2024년 요일별 현황')
sns.barplot(data=day_ride, x='요일',y='자전거번호')
# Out:
# <Axes: title={'center': '2024년 요일별 현황'}, xlabel='요일', ylabel='자전거번호'>

# %%
# 주말구분별 따릉이 인원수, 원그래프

weekend_ride = bikes.groupby('주말구분', as_index=False)[['자전거번호']].count()

plt.pie(weekend_ride['자전거번호'],labels=weekend_ride['주말구분'],autopct='%.2f%%', 
        wedgeprops={'width':0.7, 'edgecolor':'w', 'linewidth':3})
# Out:
# ([<matplotlib.patches.Wedge at 0x1e91a1dac10>,
#   <matplotlib.patches.Wedge at 0x1e91a1dafd0>],
#  [Text(0.771175933417397, 0.7844027535123819, '주말'),
#   Text(-0.7711757245805579, -0.784402958827701, '평일')],
#  [Text(0.42064141822767104, 0.42785604737039007, '25.27%'),
#   Text(-0.4206413043166679, -0.4278561593605641, '74.73%')])

# %%
# 대여시간대별 & 요일별 이용건수

hourly_weekday_ride = bikes.groupby(['시간대','요일'],as_index=False)[['자전거번호']].count()
hourly_weekday_ride.head()
# Out:
#    시간대 요일  자전거번호
# 0    0  금  23351
# 1    0  목  20715
# 2    0  수  20657
# 3    0  월  15891
# 4    0  일  23361

# %%
sns.lineplot(data=hourly_weekday_ride, x='시간대',y='자전거번호',hue='요일')
# Out:
# <Axes: xlabel='시간대', ylabel='자전거번호'>

# %%
hourly_weekday_ride2 = bikes.pivot_table(index='시간대',columns='요일',values='자전거번호',aggfunc='count')

# 열순서 지정하여 재정렬
hourly_weekday_ride2= hourly_weekday_ride2.reindex(columns=['월','화','수','목','금','토','일'])

hourly_weekday_ride2.head()
# Out:
# 요일       월      화      수      목      금      토      일
# 시간대
# 0    15891  17445  20657  20715  23351  24562  23361
# 1    10968  12197  14435  15369  17204  19326  16545
# 2     7293   7679  10355   9649  11316  13558  12211
# 3     5661   5773   7070   7143   8168  10661   8525
# 4     5823   5667   6533   6301   7037   7268   5884

# %%
plt.Figure(figsize=(8,8))
sns.heatmap(data=hourly_weekday_ride2, annot=True, fmt='d')
# Out:
# <Axes: xlabel='요일', ylabel='시간대'>

# %%
hourly_weekday_ride3 = bikes.groupby(['시간대','요일'])[['자전거번호']].count().unstack()
hourly_weekday_ride3
# Out:
#       자전거번호
# 요일        금       목       수       월      일      토       화
# 시간대
# 0     23351   20715   20657   15891  23361  24562   17445
# 1     17204   15369   14435   10968  16545  19326   12197
# 2     11316    9649   10355    7293  12211  13558    7679
# 3      8168    7143    7070    5661   8525  10661    5773
# 4      7037    6301    6533    5823   5884   7268    5667
# 5     12646   12380   13316   11864   5389   8138   12452
# 6     28336   29267   31027   26191   7786  11822   28854
# 7     66935   69323   74315   57457  13271  19417   61946
# 8    108701  103379  117672   88228  23574  35210   96193
# 9     53626   52256   56446   46148  33116  44986   47979
# 10    38696   36440   39563   33575  41175  49176   33975
# 11    45946   40873   44636   38895  47294  55139   39288
# 12    51312   44854   47307   43901  56690  64493   43680
# 13    51559   44893   44311   41313  64882  71499   45232
# 14    54880   46437   46649   42440  69511  73847   45007
# 15    62859   53477   53241   48140  72782  78575   48902
# 16    73487   70462   66991   57530  73892  79939   62685
# 17    95422   98818   96848   79416  70914  76265   90057
# 18   109488  126443  125352  100187  60778  63317  120661
# 19    63871   74527   74548   62783  47305  45313   73944
# 20    48005   56696   58266   49563  41252  38487   60016
# 21    44541   52661   52836   43957  36907  36823   55187
# 22    41575   46291   44539   37020  29875  33850   46387
# 23    27707   29178   26951   22879  20985  25736   27074

# %% [markdown]
# 인기 있는 대여소 TOP 50 (평일/주말 구분)

# %%
# 주말 인기대여소

bikes_weekend = bikes.groupby(['대여 대여소번호', '대여 대여소명', '주말구분'])['자전거번호'].count().unstack()
bikes_weekend.head()
# Out:
# 주말구분                     주말      평일
# 대여 대여소번호 대여 대여소명
# 102      망원역 1번출구 앞  1794.0  4485.0
# 103      망원역 2번출구 앞  1609.0  3149.0
# 104      합정역 1번출구 앞   976.0  2826.0
# 105      합정역 5번출구 앞   740.0  1662.0
# 106      합정역 7번출구 앞  1975.0  2915.0

# %%
weekend50 = bikes_weekend.sort_values('주말', ascending=False).head(50).reset_index()
weekend50
# Out:
# 주말구분  대여 대여소번호                  대여 대여소명      주말       평일
# 0         4217               한강공원 망원나들목  9011.0   8691.0
# 1          502       자양(뚝섬한강공원)역 1번출구 앞  7992.0  11407.0
# 2         2715              마곡나루역 2번 출구  6274.0  26543.0
# 3         1210        롯데월드타워(잠실역2번출구 쪽)  5606.0  13241.0
# 4          207             여의나루역 1번출구 앞  5410.0   8141.0
# 5         2102                  봉림교 교통섬  4907.0   9522.0
# 6         1153        발산역 1번, 9번 인근 대여소  4410.0  14136.0
# 7         2622              올림픽공원역 3번출구  4095.0   7354.0
# 8         3533         건대입구역 사거리(롯데백화점)  3872.0   8539.0
# 9         2608                     송파구청  3836.0   9732.0
# 10        4565               영등포 신세계백화점  3811.0   7857.0
# 11         230              영등포구청역 1번출구  3733.0  13572.0
# 12         765                오목교역 3번출구  3666.0   8631.0
# 13         769                 CBS방송국 앞  3622.0   7921.0
# 14        1653                  노원역1번출구  3555.0   8687.0
# 15        1124              발산역 6번 출구 뒤  3448.0   9660.0
# 16         583               청계천 생태교실 앞  3438.0   4797.0
# 17         272                    당산육갑문  3412.0   5587.0
# 18         792           목동트라팰리스 웨스턴에비뉴  3364.0   8273.0
# 19        1911               구로디지털단지역 앞  3332.0  11683.0
# 20        1009           천호역4번출구(현대백화점)  3224.0   7408.0
# 21        2728              마곡나루역 3번 출구  3198.0  16557.0
# 22        3534             건대입구역 5번출구 뒤  3179.0   8532.0
# 23        1906             신도림역 1번 출구 앞  3115.0   9345.0
# 24        2177               신대방역 2번 출구  3111.0   9638.0
# 25        2620             송파나루역 4번 출구옆  2994.0   7689.0
# 26        3511                 응봉역 1번출구  2969.0   4024.0
# 27        2701            마곡나루역 5번출구 뒤편  2881.0  18887.0
# 28         585          성수2가1동 공영주차장 인근  2860.0   7940.0
# 29        4179              보라매병원역 1번출구  2839.0   6450.0
# 30         565                 옥수역 3번출구  2834.0   5219.0
# 31         549                아차산역 3번출구  2833.0   6338.0
# 32        4870              몽촌토성역 3번 출구  2806.0   7619.0
# 33        1961               신도림테크노근린공원  2799.0   9012.0
# 34        1222            잠실새내역 5번 출구 뒤  2761.0   5853.0
# 35         746                 목동2단지 상가  2761.0   6246.0
# 36        1637           KT 전화국 버스정류장 옆  2727.0   6383.0
# 37        2219  고속터미널역 8-1번, 8-2번 출구 사이  2680.0   4533.0
# 38        5858                 영등포역5번출구  2676.0   7767.0
# 39         853                  용산역 맞은편  2660.0   4633.0
# 40        1044                    굽은다리역  2629.0   6282.0
# 41         870                 노들섬 서측 앞  2629.0   1798.0
# 42         785            양천구청, 보건소 사잇길  2616.0  10056.0
# 43        1160              양천향교역 7번출구앞  2606.0   8854.0
# 44         186                    월드컵공원  2605.0   1348.0
# 45        4540                목동역 3번 출구  2600.0   7856.0
# 46        1601       석계역 문화광장 내 자전거 보관소  2587.0   7317.0
# 47        4029                청소년수련관 후문  2585.0   7143.0
# 48         113             홍대입구역 2번출구 앞  2582.0   8910.0
# 49        3798             그랜드아이파크아파트 앞  2565.0   9027.0

# %%
bike_shop = pd.read_csv('data\대여소 정보.csv', encoding='cp949')
bike_shop.head()
# Out:
#    대여소 번호     보관소(대여소)명  자치구                             상세주소         위도  \
# 0     301   경복궁역 7번출구 앞  종로구  서울특별시 종로구 사직로 지하130 경복궁역 7번출구 앞  37.575794
# 1     302   경복궁역 4번출구 뒤  종로구  서울특별시 종로구 사직로 지하130 경복궁역 4번출구 뒤  37.575947
# 2     303   광화문역 1번출구 앞  종로구       서울특별시 종로구 세종대로 지하189 세종로공원  37.571770
# 3     305        종로구청 옆  종로구               서울특별시 종로구 세종로 84-1  37.572559
# 4     307     서울역사박물관 앞  종로구      서울특별시 종로구 새문안로 55 서울역사박물관 앞  37.570000
#
#            경도
# 0  126.971451
# 1  126.974060
# 2  126.974663
# 3  126.978332
# 4  126.971100

# %%
weekend50_total = pd.merge(weekend50, bike_shop, left_on='대여 대여소번호', right_on='대여소 번호')
weekend50_total
# Out:
#     대여 대여소번호                  대여 대여소명      주말       평일  대여소 번호  \
# 0       4217               한강공원 망원나들목  9011.0   8691.0    4217
# 1        502       자양(뚝섬한강공원)역 1번출구 앞  7992.0  11407.0     502
# 2       2715              마곡나루역 2번 출구  6274.0  26543.0    2715
# 3       1210        롯데월드타워(잠실역2번출구 쪽)  5606.0  13241.0    1210
# 4        207             여의나루역 1번출구 앞  5410.0   8141.0     207
# 5       2102                  봉림교 교통섬  4907.0   9522.0    2102
# 6       1153        발산역 1번, 9번 인근 대여소  4410.0  14136.0    1153
# 7       2622              올림픽공원역 3번출구  4095.0   7354.0    2622
# 8       3533         건대입구역 사거리(롯데백화점)  3872.0   8539.0    3533
# 9       2608                     송파구청  3836.0   9732.0    2608
# 10      4565               영등포 신세계백화점  3811.0   7857.0    4565
# 11       230              영등포구청역 1번출구  3733.0  13572.0     230
# 12       765                오목교역 3번출구  3666.0   8631.0     765
# 13       769                 CBS방송국 앞  3622.0   7921.0     769
# 14      1653                  노원역1번출구  3555.0   8687.0    1653
# 15      1124              발산역 6번 출구 뒤  3448.0   9660.0    1124
# 16       583               청계천 생태교실 앞  3438.0   4797.0     583
# 17       272                    당산육갑문  3412.0   5587.0     272
# 18       792           목동트라팰리스 웨스턴에비뉴  3364.0   8273.0     792
# 19      1911               구로디지털단지역 앞  3332.0  11683.0    1911
# 20      1009           천호역4번출구(현대백화점)  3224.0   7408.0    1009
# 21      2728              마곡나루역 3번 출구  3198.0  16557.0    2728
# 22      3534             건대입구역 5번출구 뒤  3179.0   8532.0    3534
# 23      1906             신도림역 1번 출구 앞  3115.0   9345.0    1906
# 24      2177               신대방역 2번 출구  3111.0   9638.0    2177
# 25      2620             송파나루역 4번 출구옆  2994.0   7689.0    2620
# 26      3511                 응봉역 1번출구  2969.0   4024.0    3511
# 27      2701            마곡나루역 5번출구 뒤편  2881.0  18887.0    2701
# 28       585          성수2가1동 공영주차장 인근  2860.0   7940.0     585
# 29      4179              보라매병원역 1번출구  2839.0   6450.0    4179
# 30       565                 옥수역 3번출구  2834.0   5219.0     565
# 31       549                아차산역 3번출구  2833.0   6338.0     549
# 32      4870              몽촌토성역 3번 출구  2806.0   7619.0    4870
# 33      1961               신도림테크노근린공원  2799.0   9012.0    1961
# 34      1222            잠실새내역 5번 출구 뒤  2761.0   5853.0    1222
# 35       746                 목동2단지 상가  2761.0   6246.0     746
# 36      1637           KT 전화국 버스정류장 옆  2727.0   6383.0    1637
# 37      2219  고속터미널역 8-1번, 8-2번 출구 사이  2680.0   4533.0    2219
# 38      5858                 영등포역5번출구  2676.0   7767.0    5858
# 39       853                  용산역 맞은편  2660.0   4633.0     853
# 40      1044                    굽은다리역  2629.0   6282.0    1044
# 41       870                 노들섬 서측 앞  2629.0   1798.0     870
# 42       785            양천구청, 보건소 사잇길  2616.0  10056.0     785
# 43      1160              양천향교역 7번출구앞  2606.0   8854.0    1160
# 44       186                    월드컵공원  2605.0   1348.0     186
# 45      4540                목동역 3번 출구  2600.0   7856.0    4540
# 46      1601       석계역 문화광장 내 자전거 보관소  2587.0   7317.0    1601
# 47      4029                청소년수련관 후문  2585.0   7143.0    4029
# 48       113             홍대입구역 2번출구 앞  2582.0   8910.0     113
# 49      3798             그랜드아이파크아파트 앞  2565.0   9027.0    3798
#
#                    보관소(대여소)명   자치구                                   상세주소  \
# 0                 한강공원 망원나들목   마포구                          마포구 망원동 462-8
# 1              뚝섬유원지역 1번출구 앞   광진구         서울특별시 광진구 능동로 10 뚝섬유원지역 1번출구 앞
# 2                마곡나루역 2번 출구   강서구                          강서구 마곡중앙5로 6
# 3          롯데월드타워(잠실역2번출구 쪽)   송파구                  서울특별시 송파구 올림픽로 293-19
# 4               여의나루역 1번출구 앞  영등포구                  서울특별시 영등포구 여의동로 지하343
# 5                    봉림교 교통섬   관악구                       서울특별시 관악구 관천로 52
# 6          발산역 1번, 9번 인근 대여소   강서구                     서울특별시 강서구 공항대로 281
# 7                올림픽공원역 3번출구   송파구                          송파구 방이동 89-28
# 8           건대입구역 사거리(롯데백화점)   광진구      서울특별시 광진구 능동로 92 건대입구역 사거리(롯데백화점)
# 9                       송파구청   송파구                           송파구 올림픽로 326
# 10                영등포 신세계백화점  영등포구                       영등포구 영등포4가 442-6
# 11               영등포구청역 1번출구  영등포구                   서울특별시 영등포구 당산로 111-2
# 12                 오목교역 3번출구   양천구                     서울특별시 양천구 목동동로 270
# 13                  CBS방송국 앞   양천구                           양천구 목동 917-1
# 14                   노원역1번출구   노원구            서울특별시 노원구 상계동 335-4 노원역1번출구
# 15               발산역 6번 출구 뒤   강서구                     서울특별시 강서구 공항대로 280
# 16                청계천 생태교실 앞   성동구         서울특별시 성동구 마장로39길 51 청계천 생태교실 앞
# 17                     당산육갑문  영등포구                    서울특별시 영등포구 당산로52길 3
# 18            목동트라팰리스 웨스턴에비뉴   양천구                       오목로299(이마트 출입구측)
# 19                구로디지털단지역 앞   구로구                   서울특별시 구로구 시흥대로 577-2
# 20            천호역4번출구(현대백화점)   강동구                  서울특별시 강동구 천호대로 지하 997
# 21               마곡나루역 3번 출구   강서구                         강서구 마곡동 372-23
# 22              건대입구역 5번출구 뒤   광진구        서울특별시 광진구 아차산로 236 건대입구역 5번출구 뒤
# 23              신도림역 1번 출구 앞   구로구                      서울특별시 구로구 경인로 688
# 24                신대방역 2번 출구   관악구                          신림동 신대방역 2번출구
# 25              송파나루역 4번 출구옆   송파구                           송파구 송파동 3-15
# 26                  응봉역 1번출구   성동구            서울특별시 성동구 고산자로 123 응봉동 3-10
# 27             마곡나루역 5번출구 뒤편   강서구                          강서구 마곡동 761-5
# 28           성수2가1동 공영주차장 인근   성동구  서울특별시 성동구 성수동2가 569-3 성수2가1동 공영주차장 인근
# 29               보라매병원역 1번출구   동작구                        동작구 신대방동 395-61
# 30                  옥수역 3번출구   성동구                    서울특별시 성동구 옥수동 192-2
# 31                 아차산역 3번출구   광진구             서울특별시 광진구 구의동 96 아차산역 3번출구
# 32               몽촌토성역 3번 출구   송파구                           송파구 방이동 40-6
# 33                신도림테크노근린공원   구로구                   서울특별시 구로구 새말로 121-15
# 34             잠실새내역 5번 출구 뒤   송파구                     서울특별시 송파구 백제고분로 95
# 35                  목동2단지 상가   양천구                   서울특별시  양천구 목동 902-5
# 36            KT 전화국 버스정류장 옆   노원구        서울특별시 노원구 노해로 489 노원구 상계동 719-1
# 37   고속터미널역 8-1번, 8-2번 출구 사이   서초구                  서울특별시 서초구 신반포로 지하 188
# 38                  영등포역5번출구  영등포구                                경인로 846
# 39                   용산역 맞은편   용산구                  서울특별시 용산구 한강로2가 408-5
# 40                     굽은다리역   강동구                       서울특별시  양재대로 1572
# 41                  노들섬 서측 앞   용산구                   서울특별시 용산구 이촌동 304-11
# 42             양천구청, 보건소 사잇길   양천구                          양천구 신정동 321-8
# 43               양천향교역 7번출구앞   강서구                   서울특별시 강서구 양천로 지하 341
# 44                     월드컵공원   마포구                  서울특별시 마포구 하늘공원로 108-1
# 45                 목동역 3번 출구   양천구                           양천구 목동 926-3
# 46        석계역 문화광장 내 자전거 보관소   노원구                      서울특별시 노원구 화랑로 331
# 47                 청소년수련관 후문   노원구                서울특별시 노원구 노원구 중계동 504-2
# 48              홍대입구역 2번출구 앞   마포구                      서울특별시 마포구 양화로 165
# 49              그랜드아이파크아파트 앞   강서구
#
#            위도          경도
# 0   37.555576  126.896889
# 1   37.531860  127.067192
# 2   37.566925  126.827438
# 3   37.513126  127.100960
# 4   37.527157  126.931900
# 5   37.484085  126.926888
# 6   37.558949  126.837174
# 7   37.516258  127.130592
# 8   37.539139  127.070618
# 9   37.515053  127.106270
# 10  37.518036  126.903648
# 11  37.524635  126.896217
# 12  37.524776  126.875481
# 13  37.527855  126.874672
# 14  37.656200  127.063621
# 15  37.558178  126.838455
# 16  37.567970  127.046890
# 17  37.535339  126.903679
# 18  37.525372  126.870926
# 19  37.484940  126.901321
# 20  37.538666  127.124245
# 21  37.565804  126.828079
# 22  37.540127  127.069496
# 23  37.509720  126.890099
# 24  37.487129  126.913017
# 25  37.509979  127.112312
# 26  37.551250  127.035103
# 27  37.565201  126.827316
# 28  37.536808  127.055489
# 29  37.493221  126.923431
# 30  37.541367  127.017761
# 31  37.551224  127.089706
# 32  37.517078  127.112328
# 33  37.508183  126.891334
# 34  37.511982  127.085053
# 35  37.536503  126.877747
# 36  37.654701  127.063400
# 37  37.506199  127.003944
# 38  37.516693  126.908073
# 39  37.528488  126.965843
# 40  37.545406  127.142677
# 41  37.517319  126.958298
# 42  37.517475  126.866325
# 43  37.567680  126.840897
# 44  37.563965  126.898209
# 45  37.526531  126.864456
# 46  37.615181  127.064644
# 47  37.639664  127.060417
# 48  37.557438  126.923821
# 49  37.555107  126.851547

# %%
# 자치구별 상위 50개 대여소 분포 

weekend50_total = weekend50_total.groupby('자치구')['대여 대여소번호'].count()
weekend50_total.plot(kind='barh')
# Out:
# <Axes: ylabel='자치구'>

# %%
import folium
from folium.plugins import MarkerCluster

map = folium.Map(location=[weekend50_total['위도'].mean(), weekend50_total['경도'].mean()],
           zoom_start=12, width=800, height=500)

marker = MarkerCluster().add_to(map)

for i in weekend50_total.index:
    sub_lat = weekend50_total.loc[i, '위도']
    sub_lon = weekend50_total.loc[i, '경도']
    shop = [sub_lat, sub_lon]
    sub_name = weekend50_total.loc[i, '대여 대여소명']
    folium.Marker(location=shop, popup=sub_name, icon=folium.Icon(color='red',icon='star')).add_to(marker)

map.save('map.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_101011bc51a45f4db59e7404ebae66a9 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_101011bc51a45f4db59e7404ebae66a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_101011bc51a45f4db59e7404ebae66a9 = L.map(
#                 &quot;map_101011bc51a45f4db59e7404ebae66a9&quot;,
#                 {
#                     center: [37.540150375799996, 126.96671799200001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d83ad36b5151813225f53868954e1e3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d83ad36b5151813225f53868954e1e3e.addTo(map_101011bc51a45f4db59e7404ebae66a9);
#
#
#             var marker_cluster_8617659ff76a3049a0095cbcd64be279 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_d0b732b1362f2dec92c8f320b6c2efa6 = L.marker(
#                 [37.55557632, 126.8968887],
#                 {
# }
#             ).addTo(marker_cluster_8617659ff76a3049a0095cbcd64be279);
#
#
#             var icon_d3b4ad004829080bb9de5b5c5361bef5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d0b732b1362f2dec92c8f320b6c2efa6.setIcon(icon_d3b4ad004829080bb9de5b5c5361bef5);
#
#
#         var popup_07829e4ef6a00471011f88601b5a8161 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7262795f2c8a55ce9ca20d0561de29a = $(`&lt;div id=&quot;html_e7262795f2c8a55ce9ca20d0561de29a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;한강공원 망원나들목&lt;/div&gt;`)[0];
#                 popup_07829e4ef6a00471011f88601b5a8161.setContent(html_e7262795f2c8a55ce9ca20d0561de29a);
#
#
#
#         marker_d0b732b1362f2dec92c8f320b6c2efa6.bindPopup(popup_07829e4ef6a00471011f88601b5a8161)
#         ;
#
#
#
#
#             var marker_956be9d7bebbd492db2c05e229d1412a = L.marker(
#                 [37.53186035, 127.0671921],
#                 {
# }
#             ).addTo(marker_cluster_8617659ff76a3049a0095cbcd64be279);
#
#
#             var icon_34e4d6489e2a11177242f4b14b34811d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_956be9d7bebbd492db2c05e229d1412a.setIcon(icon_34e4d6489e2a11177242f4b14b34811d);
#
#
#         var popup_25ebec2ff70e15b39c16e0f27209f465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b43ba69f175569ccba2ac2d827a14f4 = $(`&lt;div id=&quot;html_8b43ba69f175569ccba2ac2d827a14f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;자양(뚝섬한강공원)역 1번출구 앞&lt;/div&gt;`)[0];
#                 popup_25ebec2ff70e15b39c16e0f27209f465.setContent(html_8b43ba69f175569ccba2ac2d827a14f4);
#
#
#
#         marker_956be9d7bebbd492db2c05e229d1412a.bindPopup(popup_25ebec2ff70e15b39c16e0f27209f465)
#         ;
#
#
#
#
#             var marker_2ba9aa13d3905d3c31393ae5c435176a = L.marker(
#                 [37.56692505, 126.8274384],
#                 {
# }
#             ).addTo(marker_cluster_8617659ff76a3049a0095cbcd64be279);
#
#
#             var icon_85264a8c12481dcf347158ad87224e0a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_2ba9aa13d3905d3c31393ae5c435176a.setIcon(icon_85264a8c12481dcf347158ad87224e0a);
#
#
#         var popup_aaf24560c754a8eff0aa60c7e0409397 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_deb0ab9669d2fb7b50009e439bc54c01 = $(`&lt;div id=&quot;html_deb0ab9669d2fb7b50009e439bc54c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;마곡나루
